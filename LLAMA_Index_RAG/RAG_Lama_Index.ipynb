# %% [markdown]
# # Building a RAG System over LIC's New Jeevan Shanti Policy Document

# %% [markdown]
# #import

# %%
# !pip install -q llama-index llama-parse llama-index-embeddings-ollama llama-index-llms-ollama
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 6.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.0/362.0 kB 18.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.9/11.9 MB 101.0 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 66.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.5/164.5 kB 10.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 44.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.0/51.0 kB 3.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 142.6/142.6 kB 10.6 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.
# torch 2.11.0+cpu requires setuptools<82, but you have setuptools 82.0.1 which is incompatible.

# %%
# !pip install -q llama-index llama-index-embeddings-huggingface llama-index-llms-openai-like pypdf
# Out:
# WARNING: huggingface-hub 1.20.1 does not provide the extra 'inference'
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 349.5/349.5 kB 9.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 24.2 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# ipython 7.34.0 requires jedi>=0.16, which is not installed.

# %%
# !pip install -q llama-index-llms-together llama-index-embeddings-together
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 2.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.0/12.0 MB 103.3 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 22.8 MB/s eta 0:00:00
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llama-index 0.14.23 requires llama-index-llms-openai<0.8,>=0.7.0, but you have llama-index-llms-openai 0.6.26 which is incompatible.
# gradio 6.19.0 requires huggingface-hub<2.0,>=1.2.0, but you have huggingface-hub 0.36.2 which is incompatible.

# %%
# use Colab secrets instead (uncomment if you've added secrets via the key icon)
from google.colab import userdata
import os
os.environ["LLAMA_CLOUD_API_KEY"] = userdata.get("llama")
os.environ["TOGETHER_API_KEY"] = userdata.get("together")

# %%
'''# Local embedding model — runs on CPU/GPU in this notebook, no API key
LOCAL_EMBED_MODEL = "BAAI/bge-small-en-v1.5"

# Llama API — the ONLY API key used in this notebook
LLAMA_API_BASE_URL = "https://api.llama.com/compat/v1/"  # OpenAI-compatible endpoint
LLAMA_API_MODEL = "Llama-3.3-70B-Instruct"
'''

# %% [markdown]
# #upload

# %%
from google.colab import files

uploaded = files.upload()  # select the PDF in the file picker
PDF_PATH = list(uploaded.keys())[0]
# Out:
#      <input type="file" id="files-0e93bd6a-313a-403f-a542-61f6b5a11cf0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0e93bd6a-313a-403f-a542-61f6b5a11cf0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# # Parse the PDF with LlamaParse

# %%
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader

parser = LlamaParse(
    api_key=os.environ["LLAMA_CLOUD_API_KEY"],
    result_type="markdown",
    verbose=True,
)

documents = SimpleDirectoryReader(
    input_files=[PDF_PATH],
    file_extractor={".pdf": parser},
).load_data()

print(f"Parsed {len(documents)} document chunk(s) from {PDF_PATH}")
print(documents[0].text[:800])
# Out:
# /tmp/ipykernel_1194/1074987207.py:1: DeprecationWarning: The 'llama-parse' package is deprecated and will no longer receive updates. Please migrate to the new unified SDK. See https://developers.llamaindex.ai/python/cloud/llamaparse/getting_started/ and https://github.com/run-llama/llama-cloud-py/blob/main/README.md for migration instructions.
#   from llama_parse import LlamaParse
# WARNING:llama_index.core.readers.file.base:`llama-index-readers-file` package not found, some file readers will not be available if not provided by the `file_extractor` parameter.
# Started parsing the file under job_id 6df4b2b1-c38e-4182-bd3f-f9bf738b407a
# Parsed 21 document chunk(s) from Final Policy document_LICs New Jeevan Shanti_V05_logo.pdf
#
# # LIC
#
# # LIFE INSURANCE CORPORATION OF INDIA
#
# # (Established by the Life Insurance Corporation Act, 1956)
#
# Registration Number: 512
#
# # LIC’S NEW JEEVAN SHANTI (UIN: 512N338V05)
#
# ...

# %% [markdown]
# #. Chunk the text into nodes

# %%
CHUNK_SIZE = 200
CHUNK_OVERLAP = 64

# %%
from llama_index.core.node_parser import SentenceSplitter

splitter = SentenceSplitter(chunk_size=CHUNK_SIZE, chunk_overlap=CHUNK_OVERLAP)
documents = splitter.get_nodes_from_documents(documents)
print(f"Created {len(documents)} nodes")
# Out:
# Created 111 nodes

# %%
## 7. Build the vector index (Llama embeddings via Together AI)

# %%
from llama_index.core import VectorStoreIndex

index = VectorStoreIndex(documents, show_progress=True)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /usr/local/lib/python3.12/dist-packages/llama_index/core/embeddings/utils.py in resolve_embed_model(embed_model, callback_manager)
#      57             embed_model = OpenAIEmbedding()
# ---> 58             validate_openai_api_key(embed_model.api_key)  # type: ignore
#      59         except ImportError:
#
# /usr/local/lib/python3.12/dist-packages/llama_index/embeddings/openai/utils.py in validate_openai_api_key(api_key)
#     156     if not openai_api_key:
# --> 157         raise ValueError(MISSING_API_KEY_ERROR_MESSAGE)
#
# ValueError: No API key found for OpenAI.
# Please set either the OPENAI_API_KEY environment variable or openai.api_key prior to initialization.
# API keys can be found or created at https://platform.openai.com/account/api-keys
#
#
# During handling of the above exception, another exception occurred:
#
# ...

# %% [markdown]
# ## Ask questions

# %%
QUESTIONS = [
    "What is the Free Look Period and how many days does the policyholder have to return the policy?",
    "What is the Guaranteed Surrender Value (GSV) factor in policy year 1 versus policy year 5 and above?",
    "What happens if the Annuitant commits suicide within 12 months of the date of commencement of risk?",
    "How is the Additional Benefit on Death per month calculated during the Deferment Period?",
]

# %% [markdown]
# #error

# %%
.

# %%
'''
import os
from getpass import getpass

if not os.environ.get("LLAMA_CLOUD_API_KEY"):
    os.environ["LLAMA_CLOUD_API_KEY"] = getpass("Enter LLAMA_CLOUD_API_KEY (from llama.developer.meta.com): ")

from llama_index.llms.openai_like import OpenAILike

llm = OpenAILike(
    model= "Llama-3.3-70B-Instruct",
    api_base=LLAMA_API_BASE_URL,
    api_key=os.environ["LLAMA_CLOUD_API_KEY"],
    is_chat_model=True,
    temperature=0,
)

print(LLAMA_API_BASE_URL)

'''

# %%
# Out:
# https://api.llama.com/compat/v1/

# %%
'''
query_engine = index.as_query_engine(llm=llm, similarity_top_k=3)

for q in QUESTIONS:
    response = query_engine.query(q)
    print("\nQ:", q)
    print("A:", str(response).strip())
    print("Sources:", [n.node.metadata for n in response.source_nodes])



from openai import OpenAI
import os

client = OpenAI(
    api_key=os.environ["LLAMA_CLOUD_API_KEY"],
    base_url="https://api.llama.com/compat/v1/"
)

try:
    response = client.chat.completions.create(
        model="Llama-3.3-70B-Instruct",
        messages=[
            {"role": "user", "content": "Hello"}
        ]
    )
    print(response.choices[0].message.content)

except Exception as e:
    print(e)




'''
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipykernel_1871/3777807427.py in <cell line: 0>()
#       2
#       3 for q in QUESTIONS:
# ----> 4     response = query_engine.query(q)
#       5     print("\nQ:", q)
#       6     print("A:", str(response).strip())
#
# /usr/local/lib/python3.12/dist-packages/llama_index_instrumentation/dispatcher.py in wrapper(func, instance, args, kwargs)
#     411
#     412             try:
# --> 413                 result = func(*args, **kwargs)
#     414                 if isinstance(result, asyncio.Future):
#     415                     # If the result is a Future, wrap it
#
# /usr/local/lib/python3.12/dist-packages/llama_index/core/base/base_query_engine.py in query(self, str_or_query_bundle)
#      42             if isinstance(str_or_query_bundle, str):
#      43                 str_or_query_bundle = QueryBundle(str_or_query_bundle)
# ...

# %%
# Out:
# Error code: 401 - {'error': {'message': 'Authentication Error', 'type': 'authentication_error', 'param': None, 'code': 'invalid_api_key'}}

# %% [markdown]
# # solve
